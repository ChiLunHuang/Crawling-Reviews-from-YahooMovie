# %%
# Using requests to get the web content with tags.
import requests
res = requests.get('https://tw.movies.yahoo.com/movieinfo_review.html/id=6091')
print (res) # message 
print (res.text)
# Out:
# <Response [200]>
# <!doctype html public "-//w3c//dtd html 4.01//en" "http://www.w3.org/tr/html4/strict.dtd">
# <html lang="zh-tw" xmlns:og="http://ogp.me/ns#" xmlns:fb="http://www.facebook.com/2008/fbml">
# <head>
# ...

# %%
# Using BeautifulSoup to get real value from tags.
import requests
from bs4 import BeautifulSoup as bs 
res = requests.get('https://tw.movies.yahoo.com/movieinfo_review.html/id=6091')
soup = bs(res.text,'html.parser') # In python3, you have to add 'html.parser' in soup.
print(soup.text)
# Out:
# 動物方城市 Zootopia - Yahoo奇摩電影
#
#
#
#
#
#
#
#
#
#
# YUI({
#  comboBase: 'https://s.yimg.com/zz/combo?',
#  combine: true,
#  root: 'yui-s:' + YUI.version + '/'
# }).use('node', function(Y) {
# });
#
#
#
#
#
#
#
# #ygma{position:relative;z-index:2;}
# .schmve{position:absolute;top:56px;left:330px;z-index:200;height:46px}
# #ygma a,#ygma a:hover,#ygma a:visited{color:#fff;}
# #ygma #yuhead-bd{padding-bottom:6px;}
#
#
# /* customizable */
# #yUnivHead .yuhead-bullet-down{background-position:right -119px;}
#
# /* font color */
# #yUnivHead {color:#fff;}
# #yUnivHead a{color:#fff;}
# #yUnivHead a:hover{color:#fff;}
#
# #yuhead-hd #yuhead-mepanel-cont #yuhead-mepanel li.yuhead-me{border-color:#fff;}
# #yuhead-hd #yuhead-com-links-cont #yuhead-com-links li.yuhead-com-link-item{border-color:#fff;}
# .yuhead-logo h2 a{color:#fff;}
#
# /* promo color */
# #yUnivHead #yuhead-promo .yucs-promo-label{color:#fff;}
# #yUnivHead #yuhead-promo a{color:#fff;}
# ...

# %%
# Observe the web content to decide tags you want.
# In this example, i want to get the information such as  date, author and title

# According to the result, we can find that author and date in the same raw and titles have some dirty words,
# so these data have to preprocess before store into database.

import requests
from bs4 import BeautifulSoup as bs 
res = requests.get('https://tw.movies.yahoo.com/movieinfo_review.html/id=6091')
soup = bs(res.text,'html.parser')


for date in soup.select('div.date') : 
    print (date.text)

for data in soup.select('div.text') : 
    title=data.select('h4')
    #prevent from getting null value
    if len(title) > 0 and '標題：' in str(title) :
        print (title[0].text)

for data in soup.select('div.text') : 
    comment=data.select('p')
    #prevent from getting null value and dirty words
    if len(comment) > 0  and '上映日期：' not in str(comment) :
        print (comment[0].text)
# Out:
# 發表人：kyoko0968517355   發表時間：2016-04-12
# 發表人：gitnbbc   發表時間：2016-04-12
# 發表人：竜   發表時間：2016-04-12
# 發表人：ªø®¦ ÁÂ   發表時間：2016-04-11
# 發表人：草莓   發表時間：2016-04-10
# 發表人：Gemma   發表時間：2016-04-10
# 發表人：O小新O   發表時間：2016-04-10
# 發表人：hiroshihikaru   發表時間：2016-04-10
# 發表人：小琪   發表時間：2016-04-10
# 發表人：a717320012003   發表時間：2016-04-09
# 標題：很棒的一部動畫電影
# 標題：第一次覺得花錢進戲院看動畫片超級值得！！！
# 標題：Title: 真的好看 大推 誰說去電影院看動畫片是浪費錢 這麼好的動畫片當然要去戲院支持一下啦
# 標題：Title: 真心覺得好看，可以動腦又可以爽爽看
# 標題：Title: 很好看搞笑風趣中帶有教育意義 好片👍無冷場👍非常用心👍
# 標題：Title: 以前覺得看動畫是浪費錢的，但被那樹獺刺激到，第一次花錢去看動畫，好在沒讓我失望，到後來覺得裡面的動物都好有特色，故事也緊湊，而且狐狸及兔子的友情也感動到我。
# 標題：Title: 看外之後... 讓人想再去電影院刷一次... 無懈可擊的一部電影
# 標題：意外的好好看！
# 標題：Title: 狐狸根本是暖男
# 標題：不要因為它是動畫片就不去看
# 笑翻我了~~也很有劇情!!!!很值得進電影院看的一部動畫片!
# 這部動畫的內容真的非常有內涵，對大人來說有很多值得深思與反省的論點，種族歧視、偏見、自我肯定、恐懼(有點和小丑同觀點)等等，世界觀也非常吸引人，真的好看值得進戲院體驗這部電影！！！小孩的話大概看到一堆動物就瘋狂了吧哈哈哈！！
# 真的好看 大推 誰說去電影院看動畫片是浪費錢 這麼好的動畫片當然要去戲院支持一下啦
# 真心覺得好看，可以動腦又可以爽爽看
# 很好看搞笑風趣中帶有教育意義 好片👍無冷場👍非常用心👍
# 以前覺得看動畫是浪費錢的，但被那樹獺刺激到，第一次花錢去看動畫，好在沒讓我失望，到後來覺得裡面的動物都好有特色，故事也緊湊，而且狐狸及兔子的友情也感動到我。
# ...

# %%
# An example for crawling information from Yahoo reviews
# According to the result, we only get 9 raws data instead of 10, so we have to check html tag again
# and find that the last raw have differernt id name "row_last"
import requests
from bs4 import BeautifulSoup as bs 
res = requests.get('https://tw.movies.yahoo.com/movieinfo_review.html/id=6091')
soup = bs(res.text,'html.parser')
#print(soup.text)
#print (res.text)

        
for data in soup.select('div.row') :  
    date = data.select('div.date')[0]
    print (date.text)
    
    content = data.select('div.text')[0]
    title = content.select('h4')
    comment = content.select('p')
    
    if len(title) > 0 and '標題：' in str(title) :
        print (title[0].text)
    if len(comment) > 0  and '上映日期：' not in str(comment) :
        print (comment[0].text,'\n')
# Out:
# 發表人：kyoko0968517355   發表時間：2016-04-12
# 標題：很棒的一部動畫電影
# 笑翻我了~~也很有劇情!!!!很值得進電影院看的一部動畫片!
#
# 發表人：gitnbbc   發表時間：2016-04-12
# 標題：第一次覺得花錢進戲院看動畫片超級值得！！！
# 這部動畫的內容真的非常有內涵，對大人來說有很多值得深思與反省的論點，種族歧視、偏見、自我肯定、恐懼(有點和小丑同觀點)等等，世界觀也非常吸引人，真的好看值得進戲院體驗這部電影！！！小孩的話大概看到一堆動物就瘋狂了吧哈哈哈！！
#
# 發表人：竜   發表時間：2016-04-12
# 標題：Title: 真的好看 大推 誰說去電影院看動畫片是浪費錢 這麼好的動畫片當然要去戲院支持一下啦
# 真的好看 大推 誰說去電影院看動畫片是浪費錢 這麼好的動畫片當然要去戲院支持一下啦
#
# 發表人：ªø®¦ ÁÂ   發表時間：2016-04-11
# 標題：Title: 真心覺得好看，可以動腦又可以爽爽看
# 真心覺得好看，可以動腦又可以爽爽看
#
# 發表人：草莓   發表時間：2016-04-10
# 標題：Title: 很好看搞笑風趣中帶有教育意義 好片👍無冷場👍非常用心👍
# 很好看搞笑風趣中帶有教育意義 好片👍無冷場👍非常用心👍
#
# 發表人：Gemma   發表時間：2016-04-10
# 標題：Title: 以前覺得看動畫是浪費錢的，但被那樹獺刺激到，第一次花錢去看動畫，好在沒讓我失望，到後來覺得裡面的動物都好有特色，故事也緊湊，而且狐狸及兔子的友情也感動到我。
# 以前覺得看動畫是浪費錢的，但被那樹獺刺激到，第一次花錢去看動畫，好在沒讓我失望，到後來覺得裡面的動物都好有特色，故事也緊湊，而且狐狸及兔子的友情也感動到我。
#
# 發表人：O小新O   發表時間：2016-04-10
# 標題：Title: 看外之後... 讓人想再去電影院刷一次... 無懈可擊的一部電影
# 看外之後... 讓人想再去電影院刷一次... 無懈可擊的一部電影
#
# 發表人：hiroshihikaru   發表時間：2016-04-10
# 標題：意外的好好看！
# 比腦筋急轉彎更好看的動畫片 大人看的動畫片電影
#
# 發表人：小琪   發表時間：2016-04-10
# ...

# %%
# An example for crawling information from Yahoo reviews (10 reviews)

import requests
from bs4 import BeautifulSoup as bs 
res = requests.get('https://tw.movies.yahoo.com/movieinfo_review.html/id=6091')
soup = bs(res.text,'html.parser')
#print(soup.text)
#print (res.text)

# 1  to 9        
for data in soup.select('div.row') :  
    date = data.select('div.date')[0]
    print (date.text)
    
    content = data.select('div.text')[0]
    title = content.select('h4')
    comment = content.select('p')
    
    if len(title) > 0 and '標題：' in str(title) :
        print (title[0].text)
    if len(comment) > 0  and '上映日期：' not in str(comment) :
        print (comment[0].text,'\n')
# 10
for data in soup.select('div.row_last') :  
    date = data.select('div.date')[0]
    print (date.text)
    
    content = data.select('div.text')[0]
    title = content.select('h4')
    comment = content.select('p')
    
    if len(title) > 0 and '標題：' in str(title) :
        print (title[0].text)
    if len(comment) > 0  and '上映日期：' not in str(comment) :
        print (comment[0].text,'\n')
# Out:
# 發表人：kyoko0968517355   發表時間：2016-04-12
# 標題：很棒的一部動畫電影
# 笑翻我了~~也很有劇情!!!!很值得進電影院看的一部動畫片!
#
# 發表人：gitnbbc   發表時間：2016-04-12
# 標題：第一次覺得花錢進戲院看動畫片超級值得！！！
# 這部動畫的內容真的非常有內涵，對大人來說有很多值得深思與反省的論點，種族歧視、偏見、自我肯定、恐懼(有點和小丑同觀點)等等，世界觀也非常吸引人，真的好看值得進戲院體驗這部電影！！！小孩的話大概看到一堆動物就瘋狂了吧哈哈哈！！
#
# 發表人：竜   發表時間：2016-04-12
# 標題：Title: 真的好看 大推 誰說去電影院看動畫片是浪費錢 這麼好的動畫片當然要去戲院支持一下啦
# 真的好看 大推 誰說去電影院看動畫片是浪費錢 這麼好的動畫片當然要去戲院支持一下啦
#
# 發表人：ªø®¦ ÁÂ   發表時間：2016-04-11
# 標題：Title: 真心覺得好看，可以動腦又可以爽爽看
# 真心覺得好看，可以動腦又可以爽爽看
#
# 發表人：草莓   發表時間：2016-04-10
# 標題：Title: 很好看搞笑風趣中帶有教育意義 好片👍無冷場👍非常用心👍
# 很好看搞笑風趣中帶有教育意義 好片👍無冷場👍非常用心👍
#
# 發表人：Gemma   發表時間：2016-04-10
# 標題：Title: 以前覺得看動畫是浪費錢的，但被那樹獺刺激到，第一次花錢去看動畫，好在沒讓我失望，到後來覺得裡面的動物都好有特色，故事也緊湊，而且狐狸及兔子的友情也感動到我。
# 以前覺得看動畫是浪費錢的，但被那樹獺刺激到，第一次花錢去看動畫，好在沒讓我失望，到後來覺得裡面的動物都好有特色，故事也緊湊，而且狐狸及兔子的友情也感動到我。
#
# 發表人：O小新O   發表時間：2016-04-10
# 標題：Title: 看外之後... 讓人想再去電影院刷一次... 無懈可擊的一部電影
# 看外之後... 讓人想再去電影院刷一次... 無懈可擊的一部電影
#
# 發表人：hiroshihikaru   發表時間：2016-04-10
# 標題：意外的好好看！
# 比腦筋急轉彎更好看的動畫片 大人看的動畫片電影
#
# 發表人：小琪   發表時間：2016-04-10
# ...

# %%
# An example for preprocessing (author, data, titile)

import requests
from bs4 import BeautifulSoup as bs 
res = requests.get('https://tw.movies.yahoo.com/movieinfo_review.html/id=6091')
soup = bs(res.text,'html.parser')
#print(soup.text)
#print (res.text)

# 1  to 9        
for data in soup.select('div.row') :  
    date = data.select('div.date')[0]
    dateDelete = date.text.split('發表時間：')[1]
    print (dateDelete)
    author = date.text.strip().split('發表時間：')[0]
    authorDelete = author.split('發表人：')[1]
    print (authorDelete)
    
    content = data.select('div.text')[0]
    title = content.select('h4')
    comment = content.select('p')
    # Using replace or split
    if len(title) > 0 and '標題：' in str(title) :
        titleDelete = title[0].text.replace('Title: ','')
        titleDelete = titleDelete.split('標題：')[1]
        print (titleDelete)
    
    if len(comment) > 0  and '上映日期：' not in str(comment) :
        print (comment[0].text,'\n')
# 10
for data in soup.select('div.row_last') :  
    date = data.select('div.date')[0]
    dateDelete = date.text.split('發表時間：')[1]
    print (dateDelete)
    author = date.text.strip().split('發表時間：')[0]
    authorDelete = author.split('發表人：')[1]
    print (authorDelete)
    
    content = data.select('div.text')[0]
    title = content.select('h4')
    comment = content.select('p')
    
    if len(title) > 0 and '標題：' in str(title) :
        titleDelete = title[0].text.replace('Title: ','')
        titleDelete = titleDelete.split('標題：')[1]
        print (titleDelete)
    if len(comment) > 0  and '上映日期：' not in str(comment) :
        print (comment[0].text,'\n')
# Out:
# 2016-04-12
# kyoko0968517355
# 很棒的一部動畫電影
# 笑翻我了~~也很有劇情!!!!很值得進電影院看的一部動畫片!
#
# 2016-04-12
# gitnbbc
# 第一次覺得花錢進戲院看動畫片超級值得！！！
# 這部動畫的內容真的非常有內涵，對大人來說有很多值得深思與反省的論點，種族歧視、偏見、自我肯定、恐懼(有點和小丑同觀點)等等，世界觀也非常吸引人，真的好看值得進戲院體驗這部電影！！！小孩的話大概看到一堆動物就瘋狂了吧哈哈哈！！
#
# 2016-04-12
# 竜
# 真的好看 大推 誰說去電影院看動畫片是浪費錢 這麼好的動畫片當然要去戲院支持一下啦
# 真的好看 大推 誰說去電影院看動畫片是浪費錢 這麼好的動畫片當然要去戲院支持一下啦
#
# 2016-04-11
# ªø®¦ ÁÂ
# 真心覺得好看，可以動腦又可以爽爽看
# 真心覺得好看，可以動腦又可以爽爽看
#
# 2016-04-10
# 草莓
# 很好看搞笑風趣中帶有教育意義 好片👍無冷場👍非常用心👍
# 很好看搞笑風趣中帶有教育意義 好片👍無冷場👍非常用心👍
#
# 2016-04-10
# Gemma
# 以前覺得看動畫是浪費錢的，但被那樹獺刺激到，第一次花錢去看動畫，好在沒讓我失望，到後來覺得裡面的動物都好有特色，故事也緊湊，而且狐狸及兔子的友情也感動到我。
# 以前覺得看動畫是浪費錢的，但被那樹獺刺激到，第一次花錢去看動畫，好在沒讓我失望，到後來覺得裡面的動物都好有特色，故事也緊湊，而且狐狸及兔子的友情也感動到我。
#
# 2016-04-10
# O小新O
# 看外之後... 讓人想再去電影院刷一次... 無懈可擊的一部電影
# 看外之後... 讓人想再去電影院刷一次... 無懈可擊的一部電影
#
# 2016-04-10
# hiroshihikaru
# 意外的好好看！
# 比腦筋急轉彎更好看的動畫片 大人看的動畫片電影
#
# 2016-04-10
# 小琪
# 狐狸根本是暖男
# 狐狸根本是暖男
#
# 2016-04-09
# a717320012003
# 不要因為它是動畫片就不去看
# ...

# %%
# How to get star image

import requests
from bs4 import BeautifulSoup as bs 

res = requests.get('https://tw.movies.yahoo.com/movieinfo_review.html/id=6091')
soup = bs(res.text,'html.parser')


for img in soup.select('div.rate'):
    src=img.find('img')['src']
    src = src.replace('https://s.yimg.com/f/i/tw/movie/i6/rating_star_','').replace('.gif','')
    print(src.strip())
# Out:
# 5
# 5
# 5
# 5
# 5
# 4
# 5
# 5
# 5
# 5

# %%
# A completely example for information of reviews 



import requests
from bs4 import BeautifulSoup as bs 
res = requests.get('https://tw.movies.yahoo.com/movieinfo_review.html/id=6091')
soup = bs(res.text,'html.parser')
#print(soup.text)
#print (res.text)

# 1  to 9        
for data in soup.select('div.row') : 
    
    # Star
    src=data.find('img')['src']
    src = src.replace('https://s.yimg.com/f/i/tw/movie/i6/rating_star_','').replace('.gif','')
    print(src.strip())
    
    # Date
    date = data.select('div.date')[0]
    dateDelete = date.text.split('發表時間：')[1]
    print (dateDelete)
    # Author
    author = date.text.strip().split('發表時間：')[0]
    authorDelete = author.split('發表人：')[1]
    print (authorDelete)
    
    content = data.select('div.text')[0]
    title = content.select('h4')
    comment = content.select('p')
    # Title
    if len(title) > 0 and '標題：' in str(title) :
        titleDelete = title[0].text.replace('Title: ','')
        titleDelete = titleDelete.split('標題：')[1]
        print (titleDelete)
    # Comment
    if len(comment) > 0  and '上映日期：' not in str(comment) :
        print (comment[0].text,'\n')
# 10
for data in soup.select('div.row_last') :  
    
    # Star
    src=data.find('img')['src']
    src = src.replace('https://s.yimg.com/f/i/tw/movie/i6/rating_star_','').replace('.gif','')
    print(src.strip())
    
    # Date
    date = data.select('div.date')[0]
    dateDelete = date.text.split('發表時間：')[1]
    print (dateDelete)
    # Author
    author = date.text.strip().split('發表時間：')[0]
    authorDelete = author.split('發表人：')[1]
    print (authorDelete)
    
    content = data.select('div.text')[0]
    title = content.select('h4')
    comment = content.select('p')
    # Title
    if len(title) > 0 and '標題：' in str(title) :
        titleDelete = title[0].text.replace('Title: ','')
        titleDelete = titleDelete.split('標題：')[1]
        print (titleDelete)
    # Comment
    if len(comment) > 0  and '上映日期：' not in str(comment) :
        print (comment[0].text,'\n')
# Out:
# 5
# 2016-04-12
# kyoko0968517355
# 很棒的一部動畫電影
# 笑翻我了~~也很有劇情!!!!很值得進電影院看的一部動畫片!
#
# 5
# 2016-04-12
# gitnbbc
# 第一次覺得花錢進戲院看動畫片超級值得！！！
# 這部動畫的內容真的非常有內涵，對大人來說有很多值得深思與反省的論點，種族歧視、偏見、自我肯定、恐懼(有點和小丑同觀點)等等，世界觀也非常吸引人，真的好看值得進戲院體驗這部電影！！！小孩的話大概看到一堆動物就瘋狂了吧哈哈哈！！
#
# 5
# 2016-04-12
# 竜
# 真的好看 大推 誰說去電影院看動畫片是浪費錢 這麼好的動畫片當然要去戲院支持一下啦
# 真的好看 大推 誰說去電影院看動畫片是浪費錢 這麼好的動畫片當然要去戲院支持一下啦
#
# 5
# 2016-04-11
# ªø®¦ ÁÂ
# 真心覺得好看，可以動腦又可以爽爽看
# 真心覺得好看，可以動腦又可以爽爽看
#
# 5
# 2016-04-10
# 草莓
# 很好看搞笑風趣中帶有教育意義 好片👍無冷場👍非常用心👍
# 很好看搞笑風趣中帶有教育意義 好片👍無冷場👍非常用心👍
#
# 4
# 2016-04-10
# Gemma
# 以前覺得看動畫是浪費錢的，但被那樹獺刺激到，第一次花錢去看動畫，好在沒讓我失望，到後來覺得裡面的動物都好有特色，故事也緊湊，而且狐狸及兔子的友情也感動到我。
# 以前覺得看動畫是浪費錢的，但被那樹獺刺激到，第一次花錢去看動畫，好在沒讓我失望，到後來覺得裡面的動物都好有特色，故事也緊湊，而且狐狸及兔子的友情也感動到我。
#
# 5
# 2016-04-10
# O小新O
# 看外之後... 讓人想再去電影院刷一次... 無懈可擊的一部電影
# 看外之後... 讓人想再去電影院刷一次... 無懈可擊的一部電影
#
# 5
# 2016-04-10
# hiroshihikaru
# 意外的好好看！
# 比腦筋急轉彎更好看的動畫片 大人看的動畫片電影
#
# 5
# 2016-04-10
# 小琪
# 狐狸根本是暖男
# 狐狸根本是暖男
#
# 5
# 2016-04-09
# a717320012003
# 不要因為它是動畫片就不去看
# ...

# %%
#  Example for pages changing

# Find the total pages on web content

import requests
from bs4 import BeautifulSoup as bs

res = requests.get('https://tw.movies.yahoo.com/movieinfo_review.html/id=6091')

soup = bs(res.text,'html.parser')

for pages in soup.select('.statistic') :
    page = pages.text.replace('共','').split('筆，')[0]
    print (round(int(page)/10,0))
# Out:
# 28.0

# %%
# A completely example for information of reviews and changing pages
# Note: 
# 1. Find the real url (https://tw.movies.yahoo.com/movieinfo_review.html/id=6091&s=0&o=0&p=1)
# 2. Declare global varaible
# 3. The way to use format 


import requests
from bs4 import BeautifulSoup as bs 

movie_id = 6091
pages = 0

res = requests.get('https://tw.movies.yahoo.com/movieinfo_review.html/id={}&s=0&o=0&p={}'.format(movie_id,pages))
soup = bs(res.text,'html.parser')

for page in soup.select('.statistic') :
    global final_page 
    lastPages = page.text.replace('共','').split('筆，')[0]
    final_page = int(round(float(lastPages)/10,0))
    #print (final_page)


for change_page in range(pages,final_page+1) :
    
    print ('---now is up to page',change_page+1,'---')
    
    res = requests.get('https://tw.movies.yahoo.com/movieinfo_review.html/id={}&s=0&o=0&p={}'.format(movie_id,change_page))
    soup = bs(res.text,'html.parser')


    # 1  to 9        
    for data in soup.select('div.row') : 
    
        # Star
        src=data.find('img')['src']
        src = src.replace('https://s.yimg.com/f/i/tw/movie/i6/rating_star_','').replace('.gif','')
        print(src.strip())
    
        # Date
        date = data.select('div.date')[0]
        dateDelete = date.text.split('發表時間：')[1]
        print (dateDelete)
        # Author
        author = date.text.strip().split('發表時間：')[0]
        authorDelete = author.split('發表人：')[1]
        print (authorDelete)

        content = data.select('div.text')[0]
        title = content.select('h4')
        comment = content.select('p')
        # Title
        if len(title) > 0 and '標題：' in str(title) :
            titleDelete = title[0].text.replace('Title: ','')
            titleDelete = titleDelete.split('標題：')[1]
            print (titleDelete)
        # Comment
        if len(comment) > 0  and '上映日期：' not in str(comment) :
            print (comment[0].text,'\n')
    # 10
    for data in soup.select('div.row_last') :  
    
        # Star
        src=data.find('img')['src']
        src = src.replace('https://s.yimg.com/f/i/tw/movie/i6/rating_star_','').replace('.gif','')
        print(src.strip())

        # Date
        date = data.select('div.date')[0]
        dateDelete = date.text.split('發表時間：')[1]
        print (dateDelete)
        # Author
        author = date.text.strip().split('發表時間：')[0]
        authorDelete = author.split('發表人：')[1]
        print (authorDelete)

        content = data.select('div.text')[0]
        title = content.select('h4')
        comment = content.select('p')
        # Title
        if len(title) > 0 and '標題：' in str(title) :
            titleDelete = title[0].text.replace('Title: ','')
            titleDelete = titleDelete.split('標題：')[1]
            print (titleDelete)
        # Comment
        if len(comment) > 0  and '上映日期：' not in str(comment) :
            print (comment[0].text,'\n')
# Out:
# ---now is up to page 1 ---
# 5
# 2016-04-12
# kyoko0968517355
# 很棒的一部動畫電影
# 笑翻我了~~也很有劇情!!!!很值得進電影院看的一部動畫片!
#
# 5
# 2016-04-12
# gitnbbc
# 第一次覺得花錢進戲院看動畫片超級值得！！！
# 這部動畫的內容真的非常有內涵，對大人來說有很多值得深思與反省的論點，種族歧視、偏見、自我肯定、恐懼(有點和小丑同觀點)等等，世界觀也非常吸引人，真的好看值得進戲院體驗這部電影！！！小孩的話大概看到一堆動物就瘋狂了吧哈哈哈！！
#
# 5
# 2016-04-12
# 竜
# 真的好看 大推 誰說去電影院看動畫片是浪費錢 這麼好的動畫片當然要去戲院支持一下啦
# 真的好看 大推 誰說去電影院看動畫片是浪費錢 這麼好的動畫片當然要去戲院支持一下啦
#
# 5
# 2016-04-11
# ªø®¦ ÁÂ
# 真心覺得好看，可以動腦又可以爽爽看
# 真心覺得好看，可以動腦又可以爽爽看
#
# 5
# 2016-04-10
# 草莓
# 很好看搞笑風趣中帶有教育意義 好片👍無冷場👍非常用心👍
# 很好看搞笑風趣中帶有教育意義 好片👍無冷場👍非常用心👍
#
# 4
# 2016-04-10
# Gemma
# 以前覺得看動畫是浪費錢的，但被那樹獺刺激到，第一次花錢去看動畫，好在沒讓我失望，到後來覺得裡面的動物都好有特色，故事也緊湊，而且狐狸及兔子的友情也感動到我。
# 以前覺得看動畫是浪費錢的，但被那樹獺刺激到，第一次花錢去看動畫，好在沒讓我失望，到後來覺得裡面的動物都好有特色，故事也緊湊，而且狐狸及兔子的友情也感動到我。
#
# 5
# 2016-04-10
# O小新O
# 看外之後... 讓人想再去電影院刷一次... 無懈可擊的一部電影
# 看外之後... 讓人想再去電影院刷一次... 無懈可擊的一部電影
#
# 5
# 2016-04-10
# hiroshihikaru
# 意外的好好看！
# 比腦筋急轉彎更好看的動畫片 大人看的動畫片電影
#
# 5
# 2016-04-10
# 小琪
# 狐狸根本是暖男
# 狐狸根本是暖男
#
# 5
# 2016-04-09
# a717320012003
# 不要因為它是動畫片就不去看
# ...
